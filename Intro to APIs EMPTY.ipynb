# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
#200 repsone is good
#400 is bad
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
print(response.status_code)
print(response.ok)
# Out:
# 200
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
for entry in data:
   print(entry['Driver']['givenName'], entry['Driver']['familyName'])
# Out:
# Kimi Räikkönen
# Felipe Massa
# Lewis Hamilton
# Robert Kubica
# Nick Heidfeld
# Heikki Kovalainen
# Mark Webber
# Fernando Alonso
# Jarno Trulli
# Nico Rosberg
# Kazuki Nakajima
# Jenson Button
# Sébastien Bourdais
# David Coulthard
# Timo Glock
# Giancarlo Fisichella
# Rubens Barrichello
# Nelson Piquet Jr.
# Takuma Sato
# Anthony Davidson
# Adrian Sutil
# Sebastian Vettel

# %%
def get_racer_info(data):
    new_data = []
    for racer in data:
        racer_dict = {}
        racer_name = f"{racer['Driver']['givenName']}{racer['Driver']['familyName']}"
        racer_dict[racer_name] = {
            'first_name' : racer['Driver']['givenName'],
            'last_name' : racer['Driver']['familyName'],
            'position' : racer['position'],
            'wins' : racer['wins'],
            'DOB' : racer['Driver']['dateOfBirth'],
            'nationality' : racer['Driver']['nationality'],
            'constructor' : racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'KimiRäikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructor': 'Ferrari'}},
#  {'FelipeMassa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'constructor': 'Ferrari'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'RobertKubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'constructor': 'BMW Sauber'}},
#  {'NickHeidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    if response.ok:
        data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
        return get_racer_info(data)
    return "That year/round combination is not valid"

get_driver_info_by_year_and_round(2022, 1)
# Out:
# [{'CharlesLeclerc': {'first_name': 'Charles',
#    'last_name': 'Leclerc',
#    'position': '1',
#    'wins': '1',
#    'DOB': '1997-10-16',
#    'nationality': 'Monegasque',
#    'constructor': 'Ferrari'}},
#  {'CarlosSainz': {'first_name': 'Carlos',
#    'last_name': 'Sainz',
#    'position': '2',
#    'wins': '0',
#    'DOB': '1994-09-01',
#    'nationality': 'Spanish',
#    'constructor': 'Ferrari'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '0',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'GeorgeRussell': {'first_name': 'George',
#    'last_name': 'Russell',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1998-02-15',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'KevinMagnussen': {'first_name': 'Kevin',
#    'last_name': 'Magnussen',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1992-10-05',
#    'nationality': 'Danish',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
import requests
urls = ["https://pokeapi.co/api/v2/pokemon/1", "https://pokeapi.co/api/v2/pokemon/4", 
          "https://pokeapi.co/api/v2/pokemon/7", "https://pokeapi.co/api/v2/pokemon/10",
         "https://pokeapi.co/api/v2/pokemon/16"]
for url in urls:
    data = requests.get(url).json()
    print(f"Name: {data['forms'][0]['name'].title()}")
    print(f"Ability: {data['abilities'][0]['ability']['name'].title()}")
    print(f"Experience: {data['base_experience']}")
    print(f"Picture ID: {data['sprites']['front_shiny']}")
    print("Stats:")
    print(f"\tAttack: {data['stats'][0]['base_stat']}")
    print(f"\tHP: {data['stats'][1]['base_stat']}")
    print(f"\tDefense: {data['stats'][2]['base_stat']}")
    print("\n\n")
    
def get_pokemon_info(data):
    new_data = []
    for pokemon in data:
        poke_dict = {}
        poke_name = f"{data['forms'][0]['name'].title()}"
        poke_dict[poke_name] = {
            'Name': {data['forms'][0]['name'].title()},
            'Ability': {data['abilities'][0]['ability']['name'].title()},
            'Experience': {data['base_experience']},
            'Picture ID': {data['sprites']['front_shiny']},
            'Attack': {data['stats'][0]['base_stat']},
            'HP': {data['stats'][1]['base_stat']},
            'Defense': {data['stats'][2]['base_stat']}
        }
        new_data.append(poke_dict)
    return new_data

print(get_pokemon_info(data))
# Out:
# Name: Bulbasaur
# Ability: Overgrow
# Experience: 64
# Picture ID: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png
# Stats:
# 	Attack: 45
# 	HP: 49
# 	Defense: 49
#
#
#
# Name: Charmander
# Ability: Blaze
# Experience: 62
# Picture ID: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png
# Stats:
# 	Attack: 39
# 	HP: 52
# 	Defense: 43
#
#
#
# Name: Squirtle
# Ability: Torrent
# Experience: 63
# Picture ID: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/7.png
# Stats:
# 	Attack: 44
# 	HP: 48
# 	Defense: 65
#
#
#
# Name: Caterpie
# Ability: Shield-Dust
# Experience: 39
# Picture ID: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/10.png
# Stats:
# 	Attack: 45
# 	HP: 30
# 	Defense: 35
#
#
#
# Name: Pidgey
# Ability: Keen-Eye
# Experience: 50
# Picture ID: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/16.png
# Stats:
# ...
